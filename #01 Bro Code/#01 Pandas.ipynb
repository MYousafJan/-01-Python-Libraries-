# %% [markdown]
# # Day 01
# **Learning Different sort of things from Youtube like libraries**

# %%
x = int (input ("Enter a number:"))
if x%2==0:
    print ("Even")
else:
    print ("Odd")
# Out:
# Enter a number: 97
# Odd
